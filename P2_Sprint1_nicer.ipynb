# %%
import pandas as pd
import numpy as np
red_wine = pd.read_csv('/Users/cd/Documents/Code Academy Berlin/Project 2/wine+quality/winequality-red.csv', sep = ';')
red_wine_copy = red_wine.copy()
white_wine = pd.read_csv('/Users/cd/Documents/Code Academy Berlin/Project 2/wine+quality/winequality-white.csv', sep = ';')
white_wine_copy = white_wine.copy()

# %%
def add_underscores(red_wine):
    red_wine.columns = red_wine.columns.str.replace(' ', '_')
    return red_wine

# %%
red_wine = add_underscores(red_wine)
red_wine.head(5)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
def add_underscores(white_wine):
    white_wine.columns = white_wine.columns.str.replace(' ', '_')
    return white_wine

# %%
white_wine = add_underscores(white_wine)
white_wine.head(5)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# %%
# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
#here i make a column titled red_or_white in the white_wine list, and give all the white wines property 'white'

white_wine['red_or_white'] = 'white'

white_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#here i make a column titled red_or_white in the red_wine list, and give all the red wines property 'red'


red_wine['red_or_white'] = 'red'

red_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
combiwines = pd.concat([red_wine, white_wine], ignore_index=True)
combiwines
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
#here i create a combined data frame of the descriptions of red and white wines, and give them some keys for red wines stats and white wines stats

combined_wines_desc = pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
combined_wines_desc
# Out:
#       Red Wines Stats                                               \
#         fixed_acidity volatile_acidity  citric_acid residual_sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free_sulfur_dioxide total_sulfur_dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
combined_wines_desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 24 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   (Red Wines Stats, fixed_acidity)           8 non-null      float64
#  1   (Red Wines Stats, volatile_acidity)        8 non-null      float64
#  2   (Red Wines Stats, citric_acid)             8 non-null      float64
#  3   (Red Wines Stats, residual_sugar)          8 non-null      float64
#  4   (Red Wines Stats, chlorides)               8 non-null      float64
#  5   (Red Wines Stats, free_sulfur_dioxide)     8 non-null      float64
#  6   (Red Wines Stats, total_sulfur_dioxide)    8 non-null      float64
#  7   (Red Wines Stats, density)                 8 non-null      float64
#  8   (Red Wines Stats, pH)                      8 non-null      float64
#  9   (Red Wines Stats, sulphates)               8 non-null      float64
# ...

# %%
#average free sulfur dioxide is higher in white wines on all measures
#Although it is naturally produced in small amounts by wine yeast during alcoholic fermentation, most of the SO2 found in wines has been put there by the winemaker. It is added at most stages of the white winemaking process, from crushing through to bottling. It is used less liberally during red winemaking, but with an almost mandatory addition being made following the completion of the malolactic fermentation of these wines. SO2 is added in the form of a powder, or is directly fed into the wine as a gas from a dosing gun.
#https://www.aromadictionary.com/articles/sulfurdioxide_article.html
#Free sulfur dioxide: the part of the sulfur dioxide that is added to a wine and that is lost into it is said to be bound, while the active part is said to be free. The winemaker will always try to get the highest proportion of free sulfur to bind. This variable is expressed in mg/dm3 in the data.
combined_wines_desc.iloc[:,[5, 17]]
# Out:
#           Red Wines Stats   White Wines Stats
#       free_sulfur_dioxide free_sulfur_dioxide
# count         1599.000000         4898.000000
# mean            15.874922           35.308085
# std             10.460157           17.007137
# min              1.000000            2.000000
# 25%              7.000000           23.000000
# 50%             14.000000           34.000000
# 75%             21.000000           46.000000
# max             72.000000          289.000000

# %%
#max range of densities for white wines is much wider than for reds, but white average density is lower...
combined_wines_desc.iloc[:,[11,7,19,23]]
# Out:
#       Red Wines Stats              White Wines Stats
#               quality      density           density      quality
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean         5.636023     0.996747          0.994027     5.877909
# std          0.807569     0.001887          0.002991     0.885639
# min          3.000000     0.990070          0.987110     3.000000
# 25%          5.000000     0.995600          0.991723     5.000000
# 50%          6.000000     0.996750          0.993740     6.000000
# 75%          6.000000     0.997835          0.996100     6.000000
# max          8.000000     1.003690          1.038980     9.000000

# %%
#white wines have higher average and max citric acid, but that may be an outlier's fault
combined_wines_desc.iloc[:,[2,11,14,23]]
# Out:
#       Red Wines Stats              White Wines Stats
#           citric_acid      quality       citric_acid      quality
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean         0.270976     5.636023          0.334192     5.877909
# std          0.194801     0.807569          0.121020     0.885639
# min          0.000000     3.000000          0.000000     3.000000
# 25%          0.090000     5.000000          0.270000     5.000000
# 50%          0.260000     6.000000          0.320000     6.000000
# 75%          0.420000     6.000000          0.390000     6.000000
# max          1.000000     8.000000          1.660000     9.000000

# %%
#mean residual sugar appears higher in white than in red wines
combined_wines_desc.iloc[:,[3,11,15,23]]
# Out:
#       Red Wines Stats              White Wines Stats
#        residual_sugar      quality    residual_sugar      quality
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean         2.538806     5.636023          6.391415     5.877909
# std          1.409928     0.807569          5.072058     0.885639
# min          0.900000     3.000000          0.600000     3.000000
# 25%          1.900000     5.000000          1.700000     5.000000
# 50%          2.200000     6.000000          5.200000     6.000000
# 75%          2.600000     6.000000          9.900000     6.000000
# max         15.500000     8.000000         65.800000     9.000000

# %%
#You can observe that the mean value of sulfates and volatile acidity seem to be higher in red wine as compared to white wine.
cwdc.iloc[:,[3,6,9,10,1,11,15,18,21,22,13,23]]

# %%
# add column, determining whih is red, which is white
#then count red, white, from that column

white_count = combiwines['red_or_white'].value_counts()['white']
red_count = combiwines['red_or_white'].value_counts()['red']
white_count
red_count
# Out:
# 1599

# %%
combiwines['quality_label']
# Out:
# 0          low
# 1          low
# 2          low
# 3       medium
# 4          low
#          ...
# 6492    medium
# 6493       low
# 6494    medium
# 6495    medium
# 6496    medium
# Name: quality_label, Length: 6497, dtype: category
# Categories (3, object): ['low', 'medium', 'high']

# %%
#The first plot you should do is a pie chart, showing the quantity of red wines compared to the quantity of white wines.
import matplotlib.pyplot as plt

lbls = 'Red Wines', 'White Wines'
slices = [red_count,white_count]
cols = ['r','y']

plt.show()

plt.pie(slices,
        labels=lbls,
        colors=cols,
        startangle=0,
        shadow= True,
        autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x176895fd0>,
# ...
#  [Text(0.7872560399476721, 0.7682629286682453, 'Red Wines'),
#   Text(-0.7872560759126549, -0.7682628918141292, 'White Wines')],
#  [Text(0.4294123854260029, 0.4190525065463156, '24.6%'),
#   Text(-0.4294124050432663, -0.41905248644407045, '75.4%')])

# %%
red_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#Now create a plot to show the distribution of qualities. It should look similar to the one below

###to combine the graphs, you're going to have to use subplots, and share the axes (x, or y), using axs, 

#fig = plt.figure(figsize = (10, 5))


import numpy as np
import matplotlib.pyplot as plt

#this is wrong because .unique just grabs the first instances of each unique value in the quality_label column on each of these indexes

white_x = white_wine['quality_label'].unique()
red_x = red_wine['quality_label'].unique()


wwcountof_ratings = white_wine.value_counts('quality_label')

rwcountof_ratings = red_wine.value_counts('quality_label')


fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
#sharex=True doesn't work either
fig.suptitle('Wine Quality Ratings')

ax1.bar(white_x, wwcountof_ratings, color ='yellow', width = 0.4)
ax2.bar(red_x, rwcountof_ratings, color ='red', width = 0.4)

plt.show()
#this is wrong. medium should be highest value in both

# %%
red_wine.value_counts('quality_label')
# Out:
# quality_label
# medium    837
# low       744
# high       18
# dtype: int64

# %%
white_wine.value_counts('quality_label')
# Out:
# quality_label
# medium    3078
# low       1640
# high       180
# dtype: int64

# %%
combiwines['quality_label'].unique()
# Out:
# ['low', 'medium', 'high']
# Categories (3, object): ['low', 'medium', 'high']

# %%
red_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white_wine['quality_label'].value_counts().sort_index().plot.bar(figsize=(12,8))
#pandas
# Out:
# <Axes: >

# %%
red_wine['quality_label'].value_counts().sort_index().plot.bar(figsize=(12,8))
#pandas
# Out:
# <Axes: >

# %%
###still not correct. is still sorting by first occurrence of the word in the quality_label, not making a correspondence between what the value is actually

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)

#x = combiwines['quality_label']
fig.suptitle('Wine Quality Ratings')
ax1.bar(white_wine['quality_label'].unique(), white_wine['quality_label'].value_counts(sort=False), color ='yellow', width = 0.4)
ax2.bar(red_wine['quality_label'].unique(), red_wine['quality_label'].value_counts(sort=False),color ='red', width = 0.4)
plt.show()

###still not correct. is still sorting by first occurrence of the word in the quality_label, not making a correspondence between what the value is actually

# %%
#wip22
x_axis = combiwines['quality_label'].unique()
y_axis = combiwines['quality_label'].value_counts(sort=False)
plt.bar(x_axis, y_axis)
plt.show()

# %%
combiwines['quality_label'].value_counts()
# Out:
# medium    3915
# low       2384
# high       198
# Name: quality_label, dtype: int64

# %%
sorted(white_wine['quality_label'].unique())
# Out:
# ['high', 'low', 'medium']

# %%
combiwines['quality_label']
# Out:
# 0          low
# 1          low
# 2          low
# 3       medium
# 4          low
#          ...
# 6492    medium
# 6493       low
# 6494    medium
# 6495    medium
# 6496    medium
# Name: quality_label, Length: 6497, dtype: category
# Categories (3, object): ['low', 'medium', 'high']

# %%
##working in seaborn.

fig, ax = plt.subplots(1, 2, sharey=True)

sns.countplot(data=white_wine, x = 'quality_label', ax=ax[0], color='gray')
sns.countplot(data=red_wine, x = 'quality_label', ax=ax[1], color='red')
ax[0].set_title('White Wine')
ax[1].set_title('Red Wine')
plt.show()

# %%
#experimental working Seaborn plot

fig, ax = plt.subplots(1,2, sharey=True, figsize=(8,4), gridspec_kw = dict(width_ratios=[1, 2.0]))

sns.countplot(data=white_wine, x = 'quality_label', ax=ax[0], color='gray', edgecolor = "black")
sns.countplot(data=red_wine, x = 'quality_label', ax=ax[1], color='red', edgecolor = "black")
ax[0].set_title('White Wine')
ax[1].set_title('Red Wine')

plt.show()

# %%
#working seaborn boxplot

fig, ax = plt.subplots(1, 2, sharex=True, figsize=(10,5))

sns.boxplot(data=combiwines, x='quality_label', y='alcohol', ax=ax[0])
sns.boxplot(data=combiwines, x='quality_label', y='pH', ax=ax[1])

fig.suptitle('Wine Quality - Alcohol Content/pH')

ax[0].set(xlabel = 'Wine Quality Class',
          ylabel = 'Wine Alcohol %')

ax[1].set(xlabel = 'Wine Quality Class',
          ylabel = 'Wine pH')

plt.show()

# %%
#working seaborn boxplot for residual sugar

fig, ax = plt.subplots(1, 2, sharex=True, figsize=(10,5))

sns.boxplot(data=white_wine, x='quality_label', y='residual_sugar', ax=ax[0], palette=("blend:#7AB,#EDA"))
sns.boxplot(data=red_wine, x='quality_label', y='residual_sugar', ax=ax[1], palette="flare")

fig.suptitle('Wine Quality - residual sugar red v white')

ax[0].set(xlabel = 'Wine Quality Class',
          ylabel = 'White Wineresidual sugar')

ax[1].set(xlabel = 'Wine Quality Class',
          ylabel = 'Red Wine residual sugar')

plt.show()
